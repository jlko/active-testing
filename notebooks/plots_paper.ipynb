# %%
import os
os.chdir('..')

# %%
from activetesting.visualize import Visualiser
from activetesting.plotting import *

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# If you are using pre-computed results from us, please set `legacy=True`.
#
# If you have computed results yourself, set `legacy=False`.
#
# You can also just manually give paths to experiments that you want to evaluate.

# %%
# load default paths
legacy = True
if legacy:
    all_paths = LegacyPaths
    select = 6
else:
    # this contains the paths to all experiment logs
    # if you have run the scripts provided by us
    all_paths = ReproduciblePaths
    select = None

# %% [markdown]
# Note that due to random data generation, the plots showing single data draws may look significantly different for you, if you have rerun the experiments.

# %% [markdown]
# # Figure 1

# %%
# note that you could replace the paths with destinations to other experiments
path = all_paths.figure123[0]
vis = Visualiser(path)

fig, ax = figure1(vis)

# %% [markdown]
# # Figure 2

# %%
path = all_paths.figure123[0]
vis = Visualiser(path)

fig, ax = figure2(vis, select=select)

# %% [markdown]
# # Figure 3

# %%
paths = all_paths.figure123
visualisers = [
    Visualiser(paths[0]),
    Visualiser(paths[1]),
    Visualiser(paths[2], task_type='classification')
]

# %%
fig, ax = figure3(visualisers)

# %% [markdown]
# # Figure 4

# %%
paths = all_paths.figure4
visualisers = get_visualisers(paths)
names = all_paths.figure4names
# Out:
# Found no datasets saved.
# Found no datasets saved.

# %%
fig, ax = figure4(visualisers, names)

# %% [markdown]
# # Figure 5

# %%
path = all_paths.figure5
name = all_paths.figure5name
vis = Visualiser(path)
# Out:
# Found no datasets saved.

# %%
fig, ax = figure5(vis)

# %% [markdown]
# # Figure 6

# %%
paths = all_paths.figure6
visualisers = get_visualisers(paths)
names = all_paths.figure6names
# Out:
# Found no datasets saved.
# Found no datasets saved.
# Found no datasets saved.
# Found no datasets saved.

# %%
fig, ax = figure6(visualisers, names)

# %% [markdown]
# # Figure 7

# %%
path = all_paths.figure7
vis = Visualiser(path)
# Out:
# Found no datasets saved.

# %%
fig, axs = figure7(vis)
